# %%
# %%writefile calculate.py

def add_it(x,y):
    return x + y

def sub_it(x,y):
    return x - y
# Out:
# Writing calculate.py

# %%
add_it(7,5)
# Out:
# 12

# %%
sub_it(6,3)
# Out:
# 3

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6279-8B1F
#
#  Directory of C:\Users\HP\Documents
#
# 10/28/2023  09:24 PM    <DIR>          .
# 10/28/2023  09:20 PM    <DIR>          .ipynb_checkpoints
# 04/26/2023  04:45 PM            11,242 .RData
# 06/07/2023  04:29 PM            10,783 .Rhistory
# 10/09/2023  12:16 PM    <DIR>          __pycache__
# 07/08/2023  09:49 PM                 0 3
# 07/08/2023  09:50 PM                 0 5
# 04/07/2020  11:37 PM             2,436 50_Startups.csv
# 10/16/2022  07:34 PM    <DIR>          academy_app
# 12/05/2022  05:16 PM       602,289,170 academy_app.zip
# 08/12/2022  10:58 PM    <DIR>          Academy-LMS
# 10/09/2023  12:41 PM                37 ade1.txt
# 10/04/2023  03:03 PM            17,479 afternoon class python.ipynb
# 09/03/2022  03:56 PM    <DIR>          api
# 04/30/2023  12:09 PM    <DIR>          app source code
# 10/10/2022  10:20 AM        30,881,911 app-release.apk
# ...
