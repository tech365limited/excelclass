# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("hotel_booking_data.csv")
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# Pandas assignment

# 1. import the pandas library
# 2. read the data
# 3. examine the first 5 records of the data
df.head()
# 4. check the summary of the data frame i.e. column, count, data type, null using a single method
# df.info()
# 5. how many rows and columns are in the data?
df.shape
# 6. are there missing values?
df.isnull().sum()
# 7. Drop the "Company" column from the dataset.
df.drop("company", axis=1)
# 8. What are the top 5 most common country codes in the dataset?
df["country"].value_counts()[:5]
# 9. What is the name of the person who paid the highest ADR (average daily rate)?

# df.loc[df["adr"].idxmax()]
df.sort_values("adr", ascending=False)[["name","adr"]][:1]
# How much was their ADR?
# 10. What is the average (mean) number of nights for a stay across the entire data set? 
df["total_stay"] = df["stays_in_weekend_nights"] + df["stays_in_week_nights"]
round(df["total_stay"].mean(),2)
df.describe()["total_stay"]
# Feel free to round this to 2 decimal points.
# 11. What is the average total cost for a stay in the dataset? 
df["total_cost"] = df["adr"] * df["total_stay"]
round(df["total_cost"].mean(),2)
# Not average daily cost, but total stay cost. Feel free to round this to 2 decimal points.
# 12. What are the names and emails of people who made 5 "Special Requests"?
df[df["total_of_special_requests"] == 5][["name","email", "total_of_special_requests"]]
# 13. What percentage of hotel stays were classified as "repeat guests"? 
# (Do not base this off the name of the person, but instead of the is_repeated_guest column)
round((sum(df["is_repeated_guest"] == 1) / len(df)) * 100,2)

# 14. How many arrivals took place between the 1st and the 15th of the month (inclusive of 1 and 15) ?
# Bonus: Can you do this in one line of pandas code?
df["arrival_date_day_of_month"]
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 119385    30
# 119386    31
# 119387    31
# 119388    31
# 119389    29
# Name: arrival_date_day_of_month, Length: 119390, dtype: int64

# %%
def one_to_fifteen(x):
    count = 0
    if x in range(1,16):
        count = count + 1
    return count
df["arrival_date_day_of_month"].apply(one_to_fifteen).sum()
# Out:
# 58152

# %%
df["arrival_date_day_of_month"].apply(lambda x: x in range(1,16)).sum()
# Out:
# 58152

# %%
def add_num(x,y):
    return x + y
add_num(5,6)
# Out:
# 11

# %%
lambda x,y: x + y
